# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/76_attributes_heartdiseases.csv')

# %%
df.replace([-9,-18,'-9'],np.nan).head()
# Out:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  V10  ...  V67  V68  V69  V70  V71  V72  \
# 0   1   0  63   1 NaN NaN NaN NaN   1  145  ...    1    1    1    1    1    1
# 1   2   0  67   1 NaN NaN NaN NaN   4  160  ...    1    1    1    1    1    1
# 2   3   0  67   1 NaN NaN NaN NaN   4  120  ...    2    2    1    1    1    7
# 3   4   0  37   1 NaN NaN NaN NaN   3  130  ...    1    1    1    1    1    1
# 4   6   0  41   0 NaN NaN NaN NaN   2  130  ...    1    1    1    1    1    1
#
#    V73  V74  V75   V76
# 0  1.0  NaN  NaN  name
# 1  1.0  NaN  NaN  name
# 2  3.0  NaN  NaN  name
# 3  1.0  NaN  NaN  name
# 4  1.0  NaN  NaN  name
#
# [5 rows x 76 columns]

# %%
df.dtypes
# Out:
# V1      int64
# V2      int64
# V3      int64
# V4      int64
# V5      int64
#         ...
# V72     int64
# V73     int64
# V74     int64
# V75    object
# V76    object
# Length: 76, dtype: object
